# %%
import numpy as np
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.2

# %%
car_data = pd.read_csv('car_fuel_efficiency.csv')

# %%
car_data.count().max()
# Out:
# np.int64(9704)

# %%
car_data.head(5)
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0         NaN     2542.392402
# 4                  210            1.0       140.0     3460.870990
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
# 2          15.1        2018  Europe  Gasoline  Front-wheel drive        0.0
# 3          20.2        2009     USA    Diesel    All-wheel drive        2.0
# 4          14.4        2009  Europe  Gasoline    All-wheel drive        2.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# ...

# %%
car_data['fuel_type'].nunique()
# Out:
# 2

# %%
car_data.isna().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower             708
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
car_data.groupby('origin')['fuel_efficiency_mpg'].max()
# Out:
# origin
# Asia      23.759123
# Europe    25.967222
# USA       24.971452
# Name: fuel_efficiency_mpg, dtype: float64

# %%
car_data.horsepower.median()
# Out:
# np.float64(149.0)

# %%
most_freq = car_data.horsepower.value_counts().max()
most_freq
# Out:
# np.int64(142)

# %%
car_data_filled = car_data.copy()
car_data_filled.horsepower = car_data_filled.horsepower.fillna(most_freq)
car_data_filled.horsepower.median()
# Out:
# np.float64(146.0)

# %%
car_data_filled.isna().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower               0
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
car_data.groupby('origin').max()#['origin'=="Asia"]
# Out:
#         engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# origin
# Asia                    370           11.0       245.0     4661.144932
# Europe                  380           13.0       271.0     4726.977269
# USA                     380           13.0       252.0     4739.077089
#
#         acceleration  model_year fuel_type         drivetrain  num_doors  \
# origin
# Asia            22.7        2023  Gasoline  Front-wheel drive        4.0
# Europe          23.5        2023  Gasoline  Front-wheel drive        3.0
# USA             24.3        2023  Gasoline  Front-wheel drive        3.0
#
#         fuel_efficiency_mpg
# origin
# Asia              23.759123
# Europe            25.967222
# USA               24.971452

# %%
x = car_data[
    car_data['origin'] == 'Asia'
][['vehicle_weight','model_year']].head(7).to_numpy()

# %%
x
# Out:
# array([[2714.21930965, 2016.        ],
#        [2783.86897424, 2010.        ],
#        [3582.68736772, 2007.        ],
#        [2231.8081416 , 2011.        ],
#        [2659.43145076, 2016.        ],
#        [2844.22753389, 2014.        ],
#        [3761.99403819, 2019.        ]])

# %%
xtx = x.T @ x                 
xtx_inv = np.linalg.inv(xtx) 
w = xtx_inv @ x.T @ y     
w
# Out:
# array([0.01386421, 0.5049067 ])

# %%
w.sum()
# Out:
# np.float64(0.5187709081074016)
