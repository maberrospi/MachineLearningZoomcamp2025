# %%
import pickle

# %% [markdown]
# # Question 3

# %%
# This is not a script as is asked but its the same idea!
input_file = r'C:\Users\mab03\Desktop\ML-Zoomcamp\05-deployment\pipeline_v1.bin'

with open(input_file, 'rb') as f_in: 
    dv, model = pickle.load(f_in)
    
record = {
    "lead_source": "paid_ads",
    "number_of_courses_viewed": 2,
    "annual_income": 79276.0
}

X = dv.transform([record])
y_pred = model.predict_proba(X)[0, 1]
print('output:', y_pred)
# Out:
# output: 0.5336072702798061

# %% [markdown]
# # Question 4

# %%
import requests
url = "http://localhost:9696/predict/"
client = {
    "lead_source": "organic_search",
    "number_of_courses_viewed": 4,
    "annual_income": 80304.0
}
requests.post(url, json=client).json()
# Out:
# {'churn_probability': 0.5340417283801275, 'churn': True}

# %% [markdown]
# # Question 6

# %%
url = "http://localhost:9696/predict/"
client = {
    "lead_source": "organic_search",
    "number_of_courses_viewed": 4,
    "annual_income": 80304.0
}
requests.post(url, json=client).json()
# Out:
# {'churn_probability': 0.5340417283801275, 'churn': True}
